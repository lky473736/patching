# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report, f1_score, precision_score, recall_score, accuracy_score
import os
import glob

# Custom layers for the model
class ABFA(tf.keras.layers.Layer):
    def __init__(self, filters, activity_classes=6, dropout_rate=0.2, **kwargs):
        super(ABFA, self).__init__(**kwargs)
        self.filters = filters
        self.activity_classes = activity_classes
        self.dropout_rate = dropout_rate

    def build(self, input_shape):
        self.action_prototypes = self.add_weight(
            name='action_prototypes',
            shape=(self.activity_classes, input_shape[-1]),
            initializer='glorot_uniform',
            trainable=True
        )
        self.embedding_proj = layers.Dense(input_shape[-1])
        self.augment_proj = layers.Dense(input_shape[-1])
        self.bn = layers.BatchNormalization()
        self.dropout = layers.Dropout(self.dropout_rate)
        self.layer_norm = layers.LayerNormalization(epsilon=1e-6)
        super().build(input_shape)

    def call(self, inputs):
        x_proj = self.embedding_proj(inputs)
        proto_similarity = tf.einsum('btd,cd->btc', x_proj, self.action_prototypes)
        proto_attention = tf.nn.softmax(proto_similarity, axis=-1)
        enhanced = tf.einsum('btc,cd->btd', proto_attention, self.action_prototypes)
        augmented = self.augment_proj(enhanced)
        x = self.bn(inputs + augmented)
        x = self.dropout(x)
        return self.layer_norm(x)

class MST_Block(layers.Layer):
    def __init__(self, filters, kernel_sizes=(3, 5, 7), **kwargs):
        super(MST_Block, self).__init__(**kwargs)
        self.filters = filters
        self.kernel_sizes = kernel_sizes

        if len(kernel_sizes) == 3:
            self.filter_dims = [filters // 4, filters // 4, filters // 2]
        else:
            self.filter_dims = [filters // 2, filters // 2]

        self.conv_layers = []
        for i, k_size in enumerate(kernel_sizes):
            self.conv_layers.append(
                layers.DepthwiseConv1D(
                    kernel_size=k_size,
                    strides=1,
                    padding='same',
                    depth_multiplier=1
                )
            )
        self.proj_layers = [
            layers.Conv1D(self.filter_dims[i], kernel_size=1, padding='same') for i in range(len(kernel_sizes))
        ]
        self.output_proj = layers.Conv1D(filters, kernel_size=1)

    def call(self, inputs):
        outputs = []
        for conv, proj in zip(self.conv_layers, self.proj_layers):
            x = conv(inputs)
            x = proj(x)
            outputs.append(x)
        x = layers.Concatenate()(outputs)
        return self.output_proj(x)

# Function to split data into sequences
def split_sequences(data, labels, window_size, step):
    X, y = [], []
    for i in range(0, len(data) - window_size + 1, step):
        X.append(data[i:i + window_size])
        # Use the label from the last timestamp in the window
        y.append(labels[i + window_size - 1])
    return np.array(X), np.array(y)

# Function to load and process WISDM dataset
def load_wisdm_dataset(file_path):
    # Define column names
    column_names = ['user', 'activity', 'timestamp', 'x_accel', 'y_accel', 'z_accel']
    
    # Parse the file line by line
    rows = []
    with open(file_path, 'r') as file:
        for line in file:
            line = line.strip()
            if line.endswith(';'):  # Remove trailing semicolon
                line = line[:-1]
            if line:  # Skip empty lines
                try:
                    values = line.split(',')
                    if len(values) == 6:  # Ensure we have all 6 fields
                        rows.append(values)
                except Exception as e:
                    print(f"Error parsing line: {line}, Error: {e}")
    
    # Create DataFrame
    df = pd.DataFrame(rows, columns=column_names)
    
    # Convert numeric columns
    for col in ['user', 'timestamp', 'x_accel', 'y_accel', 'z_accel']:
        df[col] = pd.to_numeric(df[col], errors='coerce')
    
    return df

# Process WISDM data and prepare sequences
def prepare_wisdm_data(file_path, window_size=80, step=40):
    print("Loading WISDM dataset...")
    df = load_wisdm_dataset(file_path)
    
    # Drop rows with NaN values
    df = df.dropna()
    print(f"Dataset shape after cleaning: {df.shape}")
    
    # Check unique activities
    unique_activities = df['activity'].unique()
    print(f"Unique activities in dataset: {unique_activities}")
    
    # Encode activity labels
    label_encoder = LabelEncoder()
    encoded_labels = label_encoder.fit_transform(df['activity'])
    activity_mapping = dict(zip(label_encoder.classes_, range(len(label_encoder.classes_))))
    print("Activity mapping:", activity_mapping)
    
    # Extract features (accelerometer data)
    features = df[['x_accel', 'y_accel', 'z_accel']].values
    
    # Create sequences
    X_sequences, y_sequences = split_sequences(features, encoded_labels, window_size, step)
    print(f"X_sequences shape: {X_sequences.shape}")
    print(f"y_sequences shape: {y_sequences.shape}")
    
    # Normalize features
    n_samples, n_timestamps, n_features = X_sequences.shape
    
    # Reshape to normalize features independently
    X_reshaped = X_sequences.reshape((n_samples * n_timestamps, n_features))
    
    # Normalize
    scaler = StandardScaler()
    X_reshaped = scaler.fit_transform(X_reshaped)
    
    # Reshape back to original shape
    X_sequences = X_reshaped.reshape((n_samples, n_timestamps, n_features))
    
    # One-hot encode labels
    num_classes = len(unique_activities)
    y_onehot = tf.keras.utils.to_categorical(y_sequences, num_classes=num_classes)
    
    # Create activity labels list based on the encoder mapping
    activity_labels = [None] * num_classes
    for activity, idx in activity_mapping.items():
        activity_labels[idx] = activity
    
    return X_sequences, y_sequences, y_onehot, activity_labels

# Define the ablation model building function
def build_ablation_model(components, input_shape, num_classes):
    # Decode components
    has_ip = 1 in components  # Initial Projection
    has_mscp = 2 in components  # Multi-Scale CNN Path
    has_abfa = 3 in components  # ABFA Block
    has_mst = 4 in components  # MST_Block
    has_teb = 5 in components  # Transformer Encoder Block
    has_ch = 6 in components  # Classification Head

    # Get model name
    component_str = ""
    for comp in components:
        component_str += str(comp)

    model_name = f"model{component_str}"

    # Display name for output
    model_display_name = "Model"
    for comp in components:
        if comp == 1: model_display_name += "_IP"
        elif comp == 2: model_display_name += "_MSCP"
        elif comp == 3: model_display_name += "_ABFA"
        elif comp == 4: model_display_name += "_MST"
        elif comp == 5: model_display_name += "_TEB"
        elif comp == 6: model_display_name += "_CH"

    inputs = layers.Input(shape=input_shape, name="input_layer")
    x = inputs

    # [Initial Projection]
    if has_ip:
        x = layers.Conv1D(64, kernel_size=1, activation=None)(x)
        x = layers.BatchNormalization()(x)
        x = layers.ReLU()(x)
        x = layers.Conv1D(128, kernel_size=1, activation=None)(x)
        x = layers.BatchNormalization()(x)
        x = layers.ReLU()(x)

    # [Multi-Scale CNN Path]
    if has_mscp:
        kernel_sizes = [3, 7, 11]
        multi_scale_outputs = []
        for k in kernel_sizes:
            branch = layers.Conv1D(
                filters=128 // len(kernel_sizes),
                kernel_size=k,
                padding='same',
                activation='relu'
            )(x)
            branch = layers.BatchNormalization()(branch)
            multi_scale_outputs.append(branch)

        x = layers.Concatenate()(multi_scale_outputs)
        x = layers.Conv1D(128, kernel_size=1)(x)
        x = layers.BatchNormalization()(x)
        x = layers.ReLU()(x)

    # [ABFA block]
    if has_abfa:
        x = ABFA(filters=128, activity_classes=num_classes)(x)

    # [MST block]
    if has_mst:
        x = MST_Block(filters=128, kernel_sizes=(3, 5, 7))(x)

    # [Transformer Encoder block]
    if has_teb:
        attn_output = layers.MultiHeadAttention(num_heads=4, key_dim=64)(x, x)
        x = layers.Add()([x, attn_output])
        x = layers.LayerNormalization()(x)
        ffn_output = layers.Dense(128, activation='relu')(x)
        ffn_output = layers.Dense(128)(ffn_output)
        x = layers.Add()([x, ffn_output])
        x = layers.LayerNormalization()(x)

    # [Classification Head]
    if has_ch:
        x = layers.GlobalAveragePooling1D()(x)
        x = layers.Dense(128, activation='relu')(x)
        x = layers.Dropout(0.2)(x)
        x = layers.Dense(64, activation='relu')(x)
        outputs = layers.Dense(num_classes, activation='softmax')(x)
    else:
        outputs = x  # Fallback, should never happen

    model = models.Model(inputs=inputs, outputs=outputs, name=model_name)
    return model, model_display_name

# Evaluate model function
def evaluate_model(model, X_test, y_test, model_display_name, activity_labels, dataset_name="WISDM"):
    y_pred_probs = model.predict(X_test)
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_true = np.argmax(y_test, axis=1)

    # Calculate metrics
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')
    f1 = f1_score(y_true, y_pred, average='weighted')

    # Per-class metrics
    class_accuracy = []
    class_f1 = []

    for cls in range(len(activity_labels)):
        # Binary classification for each class
        if cls in np.unique(y_true):  # Only evaluate classes present in test set
            y_true_cls = (y_true == cls).astype(int)
            y_pred_cls = (y_pred == cls).astype(int)
            class_accuracy.append(accuracy_score(y_true_cls, y_pred_cls))
            class_f1.append(f1_score(y_true_cls, y_pred_cls, average='binary'))
        else:
            class_accuracy.append(np.nan)
            class_f1.append(np.nan)

    # Plot confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(12, 10))
    
    # Get unique indices and corresponding labels for plotting
    unique_indices = np.unique(y_true)
    present_labels = [activity_labels[i] for i in unique_indices]
    
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
               xticklabels=present_labels,
               yticklabels=present_labels)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title(f'Confusion Matrix - {model_display_name} ({dataset_name})')
    plt.tight_layout()
    plt.show()

    # Print results
    print(f"\nEvaluation Metrics for {model_display_name} on {dataset_name}:")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")

    print("\nPer-Class Metrics:")
    for i, class_name in enumerate(activity_labels):
        if i in np.unique(y_true):  # Only print for classes in test set
            print(f"{class_name}: Accuracy = {class_accuracy[i]:.4f}, F1 = {class_f1[i]:.4f}")

    # Return all metrics as a dict for later comparison
    metrics = {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1': f1,
        'class_accuracy': class_accuracy,
        'class_f1': class_f1
    }

    return metrics, y_pred

# Main code
# Set paths and parameters
file_path = "/workspace/WISDM_ar_v1.1/WISDM_ar_v1.1_raw.txt"  # Update with your actual path
window_size = 20  # WISDM dataset has 20Hz sampling rate, so 80 samples = 4 seconds
step = 10        # 50% overlap between windows

# Load and preprocess data
X_sequences, y_sequences, y_onehot, activity_labels = prepare_wisdm_data(file_path, window_size, step)

# Split into train, validation, and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X_sequences, y_onehot, test_size=0.2, random_state=42
)

X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.2, random_state=42
)

print(f"Training data shape: {X_train.shape}")
print(f"Validation data shape: {X_val.shape}")
print(f"Test data shape: {X_test.shape}")
print(f"Number of classes: {len(activity_labels)}")
print(f"Activity labels: {activity_labels}")

# Define the ablation configurations
ablation_configs = [
    [1, 2, 6],              # IP + MSCP + CH
    [1, 2, 3, 6],           # IP + MSCP + ABFA + CH
    [1, 2, 4, 6],           # IP + MSCP + MST + CH
    [1, 2, 5, 6],           # IP + MSCP + TEB + CH
    [1, 3, 6],              # IP + ABFA + CH
    [1, 3, 5, 6],           # IP + ABFA + TEB + CH
    [1, 3, 4, 6],           # IP + ABFA + MST + CH
    [1, 2, 3, 5, 6],        # IP + MSCP + ABFA + TEB + CH
    [1, 2, 3, 4, 6],        # IP + MSCP + ABFA + MST + CH
    [1, 2, 4, 5, 6],        # IP + MSCP + MST + TEB + CH
    [1, 2, 3, 4, 5, 6],     # Full model
]

# Run the ablation study
results = []

for config in ablation_configs:
    # Display model components
    component_desc = []
    if 1 in config: component_desc.append("IP")
    if 2 in config: component_desc.append("MSCP")
    if 3 in config: component_desc.append("ABFA")
    if 4 in config: component_desc.append("MST")
    if 5 in config: component_desc.append("TEB")
    if 6 in config: component_desc.append("CH")
    component_str = " _ ".join(component_desc)

    print(f"\n{'='*50}")
    print(f"Building and training model: {component_str}")
    print(f"{'='*50}")

    # Build model
    model, model_display_name = build_ablation_model(
        config, 
        input_shape=(window_size, X_train.shape[2]), 
        num_classes=len(activity_labels)
    )
    
    model.compile(
        optimizer=optimizers.Adam(learning_rate=0.0001),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    # Print model summary and parameter count
    model.summary()

    # Calculate parameter counts
    trainable_params = np.sum([np.prod(v.shape) for v in model.trainable_weights])
    non_trainable_params = np.sum([np.prod(v.shape) for v in model.non_trainable_weights])
    total_params = trainable_params + non_trainable_params

    print(f"\nTotal params: {total_params:,}")
    print(f"Trainable params: {trainable_params:,}")
    print(f"Non-trainable params: {non_trainable_params:,}")

    # Train the model
    early_stopping = callbacks.EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    )
    reduce_lr = callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-5
    )

    history = model.fit(
        X_train,
        y_train,
        epochs=100,  # Using early stopping
        batch_size=32,
        validation_data=(X_val, y_val),
        callbacks=[early_stopping, reduce_lr],
        verbose=1
    )

    # Plot training history
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title(f'Model Accuracy - {component_str}')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(f'Model Loss - {component_str}')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.tight_layout()
    plt.show()

    # Evaluate on test data
    metrics, _ = evaluate_model(model, X_test, y_test, component_str, activity_labels, "WISDM")

    # Save the results
    results.append({
        'Model': component_str,
        'Parameters': total_params,
        'Accuracy': metrics['accuracy'],
        'F1': metrics['f1'],
        'Precision': metrics['precision'],
        'Recall': metrics['recall']
    })

    # Save the model
    model_save_name = f"model{''.join(str(c) for c in config)}_WISDM"
    model.save(f"{model_save_name}.h5")
    print(f"Model saved as {model_save_name}.h5")

# Display and visualize results
results_df = pd.DataFrame(results)
print("\n\nFinal Results for WISDM Dataset:")
print(results_df.to_string(index=False))

# Create a visualization of the results
plt.figure(figsize=(14, 8))
plt.bar(np.arange(len(results_df)), results_df['Accuracy'], alpha=0.7, label='Accuracy')
plt.bar(np.arange(len(results_df)), results_df['F1'], alpha=0.7, label='F1 Score')
plt.xticks(np.arange(len(results_df)), results_df['Model'], rotation=45, ha='right')
plt.ylabel('Score')
plt.title('Model Performance Comparison (WISDM)')
plt.legend()
plt.tight_layout()
plt.show()

# Comparative visualization between models
plt.figure(figsize=(15, 10))

# Prepare the data for visualization
model_names = results_df['Model'].tolist()
accuracy_values = results_df['Accuracy'].tolist()
f1_values = results_df['F1'].tolist()
precision_values = results_df['Precision'].tolist()
recall_values = results_df['Recall'].tolist()

# Set width of bars
barWidth = 0.2
r1 = np.arange(len(model_names))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]

# Create the grouped bar chart
plt.bar(r1, accuracy_values, width=barWidth, label='Accuracy', color='skyblue')
plt.bar(r2, f1_values, width=barWidth, label='F1 Score', color='lightgreen')
plt.bar(r3, precision_values, width=barWidth, label='Precision', color='salmon')
plt.bar(r4, recall_values, width=barWidth, label='Recall', color='purple')

# Add labels and title
plt.xlabel('Model Configuration', fontweight='bold', fontsize=12)
plt.ylabel('Score', fontweight='bold', fontsize=12)
plt.title('Performance Metrics Comparison Across Model Configurations', fontweight='bold', fontsize=14)
plt.xticks([r + barWidth*1.5 for r in range(len(model_names))], model_names, rotation=45, ha='right')
plt.legend()

plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# Save results to CSV
results_df.to_csv('wisdm_ablation_results.csv', index=False)
print("Results saved to 'wisdm_ablation_results.csv'")

# Create a summary DataFrame with the best model highlighted
best_model_idx = results_df['Accuracy'].idxmax()
summary_df = results_df.copy()
summary_df['Best'] = False
summary_df.loc[best_model_idx, 'Best'] = True

print("\nBest Model Summary:")
best_model = summary_df.loc[best_model_idx]
print(f"Model: {best_model['Model']}")
print(f"Parameters: {best_model['Parameters']:,}")
print(f"Accuracy: {best_model['Accuracy']:.4f}")
print(f"F1 Score: {best_model['F1']:.4f}")
print(f"Precision: {best_model['Precision']:.4f}")
print(f"Recall: {best_model['Recall']:.4f}")
# Out:
# Loading WISDM dataset...
# Dataset shape after cleaning: (1086465, 6)
# Unique activities in dataset: ['Jogging' 'Walking' 'Upstairs' 'Downstairs' 'Sitting' 'Standing']
# Activity mapping: {'Downstairs': 0, 'Jogging': 1, 'Sitting': 2, 'Standing': 3, 'Upstairs': 4, 'Walking': 5}
# X_sequences shape: (108645, 20, 3)
# y_sequences shape: (108645,)
# Training data shape: (69532, 20, 3)
# Validation data shape: (17384, 20, 3)
# Test data shape: (21729, 20, 3)
# Number of classes: 6
# Activity labels: ['Downstairs', 'Jogging', 'Sitting', 'Standing', 'Upstairs', 'Walking']
#
# ==================================================
# Building and training model: IP _ MSCP _ CH
# ==================================================
# Model: "model126"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer (InputLayer)    [(None, 20, 3)]              0         []
#
#  conv1d_6 (Conv1D)           (None, 20, 64)               256       ['input_layer[0][0]']
#
#  batch_normalization_6 (Bat  (None, 20, 64)               256       ['conv1d_6[0][0]']
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 20, 64)               0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv1d_7 (Conv1D)           (None, 20, 128)              8320      ['re_lu_3[0][0]']
#
#  batch_normalization_7 (Bat  (None, 20, 128)              512       ['conv1d_7[0][0]']
#  chNormalization)
#
#  re_lu_4 (ReLU)              (None, 20, 128)              0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv1d_8 (Conv1D)           (None, 20, 42)               16170     ['re_lu_4[0][0]']
#
#  conv1d_9 (Conv1D)           (None, 20, 42)               37674     ['re_lu_4[0][0]']
#
#  conv1d_10 (Conv1D)          (None, 20, 42)               59178     ['re_lu_4[0][0]']
#
#  batch_normalization_8 (Bat  (None, 20, 42)               168       ['conv1d_8[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 20, 42)               168       ['conv1d_9[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 20, 42)               168       ['conv1d_10[0][0]']
#  tchNormalization)
#
#  concatenate_1 (Concatenate  (None, 20, 126)              0         ['batch_normalization_8[0][0]'
#  )                                                                  , 'batch_normalization_9[0][0]
#                                                                     ',
#                                                                      'batch_normalization_10[0][0]
#                                                                     ']
#
#  conv1d_11 (Conv1D)          (None, 20, 128)              16256     ['concatenate_1[0][0]']
#
#  batch_normalization_11 (Ba  (None, 20, 128)              512       ['conv1d_11[0][0]']
#  tchNormalization)
#
#  re_lu_5 (ReLU)              (None, 20, 128)              0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  global_average_pooling1d_1  (None, 128)                  0         ['re_lu_5[0][0]']
#   (GlobalAveragePooling1D)
#
#  dense_3 (Dense)             (None, 128)                  16512     ['global_average_pooling1d_1[0
#                                                                     ][0]']
#
#  dropout_1 (Dropout)         (None, 128)                  0         ['dense_3[0][0]']
#
#  dense_4 (Dense)             (None, 64)                   8256      ['dropout_1[0][0]']
#
#  dense_5 (Dense)             (None, 6)                    390       ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 164796 (643.73 KB)
# Trainable params: 163904 (640.25 KB)
# Non-trainable params: 892 (3.48 KB)
# __________________________________________________________________________________________________
#
# Total params: 164,796
# Trainable params: 163,904
# Non-trainable params: 892
# Epoch 1/100
# 2173/2173 [==============================] - 30s 12ms/step - loss: 0.4562 - accuracy: 0.8491 - val_loss: 0.2207 - val_accuracy: 0.9223 - lr: 1.0000e-04
# Epoch 2/100
# 2173/2173 [==============================] - 26s 12ms/step - loss: 0.2215 - accuracy: 0.9260 - val_loss: 0.1513 - val_accuracy: 0.9500 - lr: 1.0000e-04
# Epoch 3/100
# 2173/2173 [==============================] - 26s 12ms/step - loss: 0.1803 - accuracy: 0.9400 - val_loss: 0.1440 - val_accuracy: 0.9517 - lr: 1.0000e-04
# Epoch 4/100
# 2173/2173 [==============================] - 25s 12ms/step - loss: 0.1579 - accuracy: 0.9485 - val_loss: 0.1258 - val_accuracy: 0.9603 - lr: 1.0000e-04
# Epoch 5/100
# 2173/2173 [==============================] - 22s 10ms/step - loss: 0.1400 - accuracy: 0.9539 - val_loss: 0.1250 - val_accuracy: 0.9597 - lr: 1.0000e-04
# Epoch 6/100
# 2173/2173 [==============================] - 22s 10ms/step - loss: 0.1307 - accuracy: 0.9572 - val_loss: 0.1132 - val_accuracy: 0.9626 - lr: 1.0000e-04
# 2173/2173 [==============================] - 23s 11ms/step - loss: 0.0321 - accuracy: 0.9894 - val_loss: 0.0877 - val_accuracy: 0.9769 - lr: 2.5000e-05
# Epoch 40/100
# 2173/2173 [==============================] - 22s 10ms/step - loss: 0.0326 - accuracy: 0.9896 - val_loss: 0.0884 - val_accuracy: 0.9769 - lr: 2.5000e-05
# 680/680 [==============================] - 1s 1ms/step
# Evaluation Metrics for IP _ MSCP _ CH on WISDM:
# Accuracy: 0.9751
# Precision: 0.9752
# Recall: 0.9751
# F1 Score: 0.9751
#
# Per-Class Metrics:
# Downstairs: Accuracy = 0.9857, F1 = 0.9222
# Jogging: Accuracy = 0.9947, F1 = 0.9915
# Sitting: Accuracy = 0.9989, F1 = 0.9898
# Standing: Accuracy = 0.9984, F1 = 0.9815
# Upstairs: Accuracy = 0.9820, F1 = 0.9211
# Walking: Accuracy = 0.9904, F1 = 0.9876
# Model saved as model126_WISDM.h5
#
# ==================================================
# Building and training model: IP _ MSCP _ ABFA _ CH
# ==================================================
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model: "model1236"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer (InputLayer)    [(None, 20, 3)]              0         []
#
#  conv1d_12 (Conv1D)          (None, 20, 64)               256       ['input_layer[0][0]']
#
#  batch_normalization_12 (Ba  (None, 20, 64)               256       ['conv1d_12[0][0]']
#  tchNormalization)
#
#  re_lu_6 (ReLU)              (None, 20, 64)               0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv1d_13 (Conv1D)          (None, 20, 128)              8320      ['re_lu_6[0][0]']
#
#  batch_normalization_13 (Ba  (None, 20, 128)              512       ['conv1d_13[0][0]']
#  tchNormalization)
#
#  re_lu_7 (ReLU)              (None, 20, 128)              0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv1d_14 (Conv1D)          (None, 20, 42)               16170     ['re_lu_7[0][0]']
#
#  conv1d_15 (Conv1D)          (None, 20, 42)               37674     ['re_lu_7[0][0]']
#
#  conv1d_16 (Conv1D)          (None, 20, 42)               59178     ['re_lu_7[0][0]']
#
#  batch_normalization_14 (Ba  (None, 20, 42)               168       ['conv1d_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_15 (Ba  (None, 20, 42)               168       ['conv1d_15[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 20, 42)               168       ['conv1d_16[0][0]']
#  tchNormalization)
#
#  concatenate_2 (Concatenate  (None, 20, 126)              0         ['batch_normalization_14[0][0]
#  )                                                                  ',
#                                                                      'batch_normalization_15[0][0]
#                                                                     ',
#                                                                      'batch_normalization_16[0][0]
#                                                                     ']
#
#  conv1d_17 (Conv1D)          (None, 20, 128)              16256     ['concatenate_2[0][0]']
#
#  batch_normalization_17 (Ba  (None, 20, 128)              512       ['conv1d_17[0][0]']
#  tchNormalization)
#
#  re_lu_8 (ReLU)              (None, 20, 128)              0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  abfa (ABFA)                 (None, 20, 128)              34560     ['re_lu_8[0][0]']
#
#  global_average_pooling1d_2  (None, 128)                  0         ['abfa[0][0]']
#   (GlobalAveragePooling1D)
#
#  dense_6 (Dense)             (None, 128)                  16512     ['global_average_pooling1d_2[0
#                                                                     ][0]']
#
#  dropout_2 (Dropout)         (None, 128)                  0         ['dense_6[0][0]']
#
# 2173/2173 [==============================] - 33s 15ms/step - loss: 0.0515 - accuracy: 0.9832 - val_loss: 0.0962 - val_accuracy: 0.9744 - lr: 2.5000e-05
# Epoch 32/100
# 2173/2173 [==============================] - 32s 15ms/step - loss: 0.0510 - accuracy: 0.9835 - val_loss: 0.0961 - val_accuracy: 0.9747 - lr: 2.5000e-05
# Epoch 33/100
# 2173/2173 [==============================] - 33s 15ms/step - loss: 0.0503 - accuracy: 0.9835 - val_loss: 0.0963 - val_accuracy: 0.9746 - lr: 2.5000e-05
# Epoch 34/100
# 2173/2173 [==============================] - 33s 15ms/step - loss: 0.0495 - accuracy: 0.9835 - val_loss: 0.1019 - val_accuracy: 0.9742 - lr: 2.5000e-05
# Epoch 35/100
# 2173/2173 [==============================] - 31s 14ms/step - loss: 0.0463 - accuracy: 0.9850 - val_loss: 0.0969 - val_accuracy: 0.9744 - lr: 1.2500e-05
# Epoch 36/100
# 2173/2173 [==============================] - 30s 14ms/step - loss: 0.0450 - accuracy: 0.9856 - val_loss: 0.0988 - val_accuracy: 0.9753 - lr: 1.2500e-05
# Epoch 37/100
# 2173/2173 [==============================] - 32s 15ms/step - loss: 0.0456 - accuracy: 0.9846 - val_loss: 0.0977 - val_accuracy: 0.9748 - lr: 1.2500e-05
# Epoch 38/100
# 2173/2173 [==============================] - 31s 14ms/step - loss: 0.0445 - accuracy: 0.9851 - val_loss: 0.0984 - val_accuracy: 0.9753 - lr: 1.2500e-05
# Epoch 39/100
# 2173/2173 [==============================] - 29s 13ms/step - loss: 0.0458 - accuracy: 0.9853 - val_loss: 0.1005 - val_accuracy: 0.9751 - lr: 1.2500e-05
# 680/680 [==============================] - 2s 2ms/step
# Evaluation Metrics for IP _ MSCP _ ABFA _ CH on WISDM:
# Accuracy: 0.9724
# Precision: 0.9724
# Recall: 0.9724
# F1 Score: 0.9724
#
# Per-Class Metrics:
# Downstairs: Accuracy = 0.9832, F1 = 0.9082
# Jogging: Accuracy = 0.9943, F1 = 0.9909
# Sitting: Accuracy = 0.9987, F1 = 0.9877
# Standing: Accuracy = 0.9983, F1 = 0.9793
# Upstairs: Accuracy = 0.9800, F1 = 0.9124
# Walking: Accuracy = 0.9903, F1 = 0.9875
# Model saved as model1236_WISDM.h5
#
# ==================================================
# Building and training model: IP _ MSCP _ MST _ CH
# ==================================================
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model: "model1246"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer (InputLayer)    [(None, 20, 3)]              0         []
#
#  conv1d_18 (Conv1D)          (None, 20, 64)               256       ['input_layer[0][0]']
#
#  batch_normalization_18 (Ba  (None, 20, 64)               256       ['conv1d_18[0][0]']
#  tchNormalization)
#
#  re_lu_9 (ReLU)              (None, 20, 64)               0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv1d_19 (Conv1D)          (None, 20, 128)              8320      ['re_lu_9[0][0]']
#
#  batch_normalization_19 (Ba  (None, 20, 128)              512       ['conv1d_19[0][0]']
#  tchNormalization)
#
#  re_lu_10 (ReLU)             (None, 20, 128)              0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv1d_20 (Conv1D)          (None, 20, 42)               16170     ['re_lu_10[0][0]']
#
#  conv1d_21 (Conv1D)          (None, 20, 42)               37674     ['re_lu_10[0][0]']
#
#  conv1d_22 (Conv1D)          (None, 20, 42)               59178     ['re_lu_10[0][0]']
#
#  batch_normalization_20 (Ba  (None, 20, 42)               168       ['conv1d_20[0][0]']
#  tchNormalization)
#
#  batch_normalization_21 (Ba  (None, 20, 42)               168       ['conv1d_21[0][0]']
#  tchNormalization)
#
#  batch_normalization_22 (Ba  (None, 20, 42)               168       ['conv1d_22[0][0]']
#  tchNormalization)
#
#  concatenate_3 (Concatenate  (None, 20, 126)              0         ['batch_normalization_20[0][0]
#  )                                                                  ',
#                                                                      'batch_normalization_21[0][0]
#                                                                     ',
#                                                                      'batch_normalization_22[0][0]
#                                                                     ']
#
#  conv1d_23 (Conv1D)          (None, 20, 128)              16256     ['concatenate_3[0][0]']
#
#  batch_normalization_23 (Ba  (None, 20, 128)              512       ['conv1d_23[0][0]']
#  tchNormalization)
#
#  re_lu_11 (ReLU)             (None, 20, 128)              0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  mst__block (MST_Block)      (None, 20, 128)              35328     ['re_lu_11[0][0]']
#
#  global_average_pooling1d_3  (None, 128)                  0         ['mst__block[0][0]']
#   (GlobalAveragePooling1D)
#
#  dense_9 (Dense)             (None, 128)                  16512     ['global_average_pooling1d_3[0
#                                                                     ][0]']
#
#  dropout_3 (Dropout)         (None, 128)                  0         ['dense_9[0][0]']
#
#  dense_10 (Dense)            (None, 64)                   8256      ['dropout_3[0][0]']
#
#  dense_11 (Dense)            (None, 6)                    390       ['dense_10[0][0]']
#
# ==================================================================================================
# Total params: 200124 (781.73 KB)
# Trainable params: 199232 (778.25 KB)
# Non-trainable params: 892 (3.48 KB)
# __________________________________________________________________________________________________
#
# Total params: 200,124
# Trainable params: 199,232
# Non-trainable params: 892
# Epoch 1/100
# 2173/2173 [==============================] - 32s 12ms/step - loss: 0.4495 - accuracy: 0.8437 - val_loss: 0.2180 - val_accuracy: 0.9283 - lr: 1.0000e-04
# Epoch 2/100
# 2173/2173 [==============================] - 29s 13ms/step - loss: 0.2234 - accuracy: 0.9244 - val_loss: 0.1612 - val_accuracy: 0.9460 - lr: 1.0000e-04
# Epoch 3/100
# 2173/2173 [==============================] - 29s 13ms/step - loss: 0.1823 - accuracy: 0.9404 - val_loss: 0.1468 - val_accuracy: 0.9523 - lr: 1.0000e-04
# Epoch 4/100
# 2173/2173 [==============================] - 29s 13ms/step - loss: 0.1611 - accuracy: 0.9471 - val_loss: 0.1338 - val_accuracy: 0.9574 - lr: 1.0000e-04
# Epoch 5/100
# 2173/2173 [==============================] - 28s 13ms/step - loss: 0.1474 - accuracy: 0.9518 - val_loss: 0.1244 - val_accuracy: 0.9608 - lr: 1.0000e-04
# Epoch 6/100
# 2173/2173 [==============================] - 31s 14ms/step - loss: 0.1354 - accuracy: 0.9556 - val_loss: 0.1194 - val_accuracy: 0.9637 - lr: 1.0000e-04
# Epoch 7/100
# 2173/2173 [==============================] - 32s 15ms/step - loss: 0.1276 - accuracy: 0.9585 - val_loss: 0.1278 - val_accuracy: 0.9605 - lr: 1.0000e-04
# Epoch 8/100
# Epoch 41/100
# 2173/2173 [==============================] - 28s 13ms/step - loss: 0.0277 - accuracy: 0.9915 - val_loss: 0.0949 - val_accuracy: 0.9769 - lr: 2.5000e-05
# Epoch 42/100
# 2173/2173 [==============================] - 27s 13ms/step - loss: 0.0286 - accuracy: 0.9910 - val_loss: 0.0927 - val_accuracy: 0.9775 - lr: 2.5000e-05
# Epoch 43/100
# 2173/2173 [==============================] - 27s 12ms/step - loss: 0.0276 - accuracy: 0.9912 - val_loss: 0.0912 - val_accuracy: 0.9770 - lr: 2.5000e-05
# Epoch 44/100
# 2173/2173 [==============================] - 27s 12ms/step - loss: 0.0284 - accuracy: 0.9909 - val_loss: 0.0937 - val_accuracy: 0.9765 - lr: 2.5000e-05
# 680/680 [==============================] - 2s 3ms/step
# Evaluation Metrics for IP _ MSCP _ MST _ CH on WISDM:
# Accuracy: 0.9732
# Precision: 0.9735
# Recall: 0.9732
# F1 Score: 0.9733
#
# Per-Class Metrics:
# Downstairs: Accuracy = 0.9841, F1 = 0.9149
# Jogging: Accuracy = 0.9944, F1 = 0.9910
# Sitting: Accuracy = 0.9987, F1 = 0.9877
# Standing: Accuracy = 0.9984, F1 = 0.9809
# Upstairs: Accuracy = 0.9821, F1 = 0.9205
# Walking: Accuracy = 0.9888, F1 = 0.9855
# Model saved as model1246_WISDM.h5
#
# ==================================================
# Building and training model: IP _ MSCP _ TEB _ CH
# ==================================================
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model: "model1256"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer (InputLayer)    [(None, 20, 3)]              0         []
#
#  conv1d_28 (Conv1D)          (None, 20, 64)               256       ['input_layer[0][0]']
#
#  batch_normalization_24 (Ba  (None, 20, 64)               256       ['conv1d_28[0][0]']
#  tchNormalization)
#
#  re_lu_12 (ReLU)             (None, 20, 64)               0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv1d_29 (Conv1D)          (None, 20, 128)              8320      ['re_lu_12[0][0]']
#
#  batch_normalization_25 (Ba  (None, 20, 128)              512       ['conv1d_29[0][0]']
#  tchNormalization)
#
#  re_lu_13 (ReLU)             (None, 20, 128)              0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv1d_30 (Conv1D)          (None, 20, 42)               16170     ['re_lu_13[0][0]']
#
#  conv1d_31 (Conv1D)          (None, 20, 42)               37674     ['re_lu_13[0][0]']
#
#  conv1d_32 (Conv1D)          (None, 20, 42)               59178     ['re_lu_13[0][0]']
#
#  batch_normalization_26 (Ba  (None, 20, 42)               168       ['conv1d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_27 (Ba  (None, 20, 42)               168       ['conv1d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_28 (Ba  (None, 20, 42)               168       ['conv1d_32[0][0]']
#  tchNormalization)
#
#  concatenate_4 (Concatenate  (None, 20, 126)              0         ['batch_normalization_26[0][0]
#  )                                                                  ',
#                                                                      'batch_normalization_27[0][0]
#                                                                     ',
# ...
#  re_lu_31 (ReLU)             (None, 20, 128)              0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  conv1d_72 (Conv1D)          (None, 20, 42)               16170     ['re_lu_31[0][0]']
#
#  conv1d_73 (Conv1D)          (None, 20, 42)               37674     ['re_lu_31[0][0]']
#
#  conv1d_74 (Conv1D)          (None, 20, 42)               59178     ['re_lu_31[0][0]']
#
#  batch_normalization_56 (Ba  (None, 20, 42)               168       ['conv1d_72[0][0]']
#  tchNormalization)
#
#  batch_normalization_57 (Ba  (None, 20, 42)               168       ['conv1d_73[0][0]']
#  tchNormalization)
#
#  batch_normalization_58 (Ba  (None, 20, 42)               168       ['conv1d_74[0][0]']
#  tchNormalization)
#
#  concatenate_8 (Concatenate  (None, 20, 126)              0         ['batch_normalization_56[0][0]
#  )                                                                  ',
#                                                                      'batch_normalization_57[0][0]
#                                                                     ',
#                                                                      'batch_normalization_58[0][0]
#                                                                     ']
#
#  conv1d_75 (Conv1D)          (None, 20, 128)              16256     ['concatenate_8[0][0]']
#
#  batch_normalization_59 (Ba  (None, 20, 128)              512       ['conv1d_75[0][0]']
#  tchNormalization)
#
#  re_lu_32 (ReLU)             (None, 20, 128)              0         ['batch_normalization_59[0][0]
#                                                                     ']
#
#  abfa_6 (ABFA)               (None, 20, 128)              34560     ['re_lu_32[0][0]']
#
#  mst__block_4 (MST_Block)    (None, 20, 128)              35328     ['abfa_6[0][0]']
#
#  multi_head_attention_4 (Mu  (None, 20, 128)              131968    ['mst__block_4[0][0]',
#  ltiHeadAttention)                                                   'mst__block_4[0][0]']
#
#  add_8 (Add)                 (None, 20, 128)              0         ['mst__block_4[0][0]',
#                                                                      'multi_head_attention_4[0][0]
#                                                                     ']
#
#  layer_normalization_8 (Lay  (None, 20, 128)              256       ['add_8[0][0]']
#  erNormalization)
#
#  dense_41 (Dense)            (None, 20, 128)              16512     ['layer_normalization_8[0][0]'
#                                                                     ]
#
#  dense_42 (Dense)            (None, 20, 128)              16512     ['dense_41[0][0]']
#
#  add_9 (Add)                 (None, 20, 128)              0         ['layer_normalization_8[0][0]'
#                                                                     , 'dense_42[0][0]']
#
#  layer_normalization_9 (Lay  (None, 20, 128)              256       ['add_9[0][0]']
#  erNormalization)
#
#  global_average_pooling1d_1  (None, 128)                  0         ['layer_normalization_9[0][0]'
#  1 (GlobalAveragePooling1D)                                         ]
#
#  dense_43 (Dense)            (None, 128)                  16512     ['global_average_pooling1d_11[
#                                                                     0][0]']
#
#  dropout_11 (Dropout)        (None, 128)                  0         ['dense_43[0][0]']
#
#  dense_44 (Dense)            (None, 64)                   8256      ['dropout_11[0][0]']
#
#  dense_45 (Dense)            (None, 6)                    390       ['dense_44[0][0]']
#
# ==================================================================================================
# Total params: 400188 (1.53 MB)
# Trainable params: 399040 (1.52 MB)
# Non-trainable params: 1148 (4.48 KB)
# __________________________________________________________________________________________________
#
# Total params: 400,188
# Trainable params: 399,040
# Non-trainable params: 1,148
# Epoch 1/100
# 2173/2173 [==============================] - 51s 20ms/step - loss: 0.3831 - accuracy: 0.8706 - val_loss: 0.2135 - val_accuracy: 0.9236 - lr: 1.0000e-04
# Epoch 2/100
# Epoch 35/100
# 2173/2173 [==============================] - 51s 24ms/step - loss: 0.0378 - accuracy: 0.9874 - val_loss: 0.1168 - val_accuracy: 0.9707 - lr: 5.0000e-05
# Epoch 36/100
# 2173/2173 [==============================] - 50s 23ms/step - loss: 0.0319 - accuracy: 0.9895 - val_loss: 0.0940 - val_accuracy: 0.9757 - lr: 2.5000e-05
# Epoch 37/100
# 2173/2173 [==============================] - 50s 23ms/step - loss: 0.0312 - accuracy: 0.9896 - val_loss: 0.1010 - val_accuracy: 0.9753 - lr: 2.5000e-05
# Epoch 38/100
# 2173/2173 [==============================] - 49s 22ms/step - loss: 0.0305 - accuracy: 0.9902 - val_loss: 0.0952 - val_accuracy: 0.9765 - lr: 2.5000e-05
# Epoch 39/100
# 2173/2173 [==============================] - 51s 24ms/step - loss: 0.0288 - accuracy: 0.9905 - val_loss: 0.1005 - val_accuracy: 0.9755 - lr: 2.5000e-05
# Epoch 40/100
# 2173/2173 [==============================] - 52s 24ms/step - loss: 0.0283 - accuracy: 0.9907 - val_loss: 0.1019 - val_accuracy: 0.9752 - lr: 2.5000e-05
# 680/680 [==============================] - 4s 5ms/step
# Evaluation Metrics for IP _ MSCP _ ABFA _ MST _ TEB _ CH on WISDM:
# Accuracy: 0.9733
# Precision: 0.9733
# Recall: 0.9733
# F1 Score: 0.9733
#
# Per-Class Metrics:
# Downstairs: Accuracy = 0.9845, F1 = 0.9153
# Jogging: Accuracy = 0.9943, F1 = 0.9909
# Sitting: Accuracy = 0.9985, F1 = 0.9865
# Standing: Accuracy = 0.9982, F1 = 0.9782
# Upstairs: Accuracy = 0.9811, F1 = 0.9170
# Walking: Accuracy = 0.9899, F1 = 0.9869
# Model saved as model123456_WISDM.h5
#
#
# Final Results for WISDM Dataset:
#                             Model  Parameters  Accuracy       F1  Precision   Recall
#                    IP _ MSCP _ CH      164796  0.975056 0.975101   0.975161 0.975056
#             IP _ MSCP _ ABFA _ CH      199356  0.972387 0.972394   0.972409 0.972387
#              IP _ MSCP _ MST _ CH      200124  0.973216 0.973279   0.973470 0.973216
#              IP _ MSCP _ TEB _ CH      330300  0.968797 0.968786   0.968786 0.968797
#                    IP _ ABFA _ CH       69062  0.939068 0.938238   0.937857 0.939068
#              IP _ ABFA _ TEB _ CH      234566  0.953610 0.953268   0.953007 0.953610
#              IP _ ABFA _ MST _ CH      104390  0.929127 0.928298   0.928286 0.929127
#       IP _ MSCP _ ABFA _ TEB _ CH      364860  0.969074 0.968975   0.968904 0.969074
#       IP _ MSCP _ ABFA _ MST _ CH      234684  0.968567 0.968553   0.968647 0.968567
#        IP _ MSCP _ MST _ TEB _ CH      365628  0.973077 0.973068   0.973092 0.973077
# IP _ MSCP _ ABFA _ MST _ TEB _ CH      400188  0.973262 0.973253   0.973257 0.973262
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Results saved to 'wisdm_ablation_results.csv'
#
# Best Model Summary:
# Model: IP _ MSCP _ CH
# Parameters: 164,796
# Accuracy: 0.9751
# F1 Score: 0.9751
# Precision: 0.9752
# Recall: 0.9751
